# %%
import pandas as pd

# %%
data=pd.date_range(start='1-1-2020',end='12-31-2020')
data
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
data=pd.date_range(start='1-1-2020',end='12-31-2020', periods=12)
data
# Out:
# DatetimeIndex([          '2020-01-01 00:00:00',
#                '2020-02-03 04:21:49.090909091',
#                '2020-03-07 08:43:38.181818182',
#                '2020-04-09 13:05:27.272727273',
#                '2020-05-12 17:27:16.363636364',
#                '2020-06-14 21:49:05.454545456',
#                '2020-07-18 02:10:54.545454546',
#                '2020-08-20 06:32:43.636363636',
#                '2020-09-22 10:54:32.727272728',
#                '2020-10-25 15:16:21.818181820',
#                '2020-11-27 19:38:10.909090912',
#                          '2020-12-31 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
data=pd.date_range(start='1-1-2020',end='12-31-2020', freq='M')
data
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
data=pd.date_range(start='1-1-2020',end='12-31-2020', freq='3M')
data
# Out:
# DatetimeIndex(['2020-01-31', '2020-04-30', '2020-07-31', '2020-10-31'], dtype='datetime64[ns]', freq='3M')

# %%
data=pd.date_range(start='1-1-2010',end='12-31-2020', freq='Y')
data
# Out:
# DatetimeIndex(['2010-12-31', '2011-12-31', '2012-12-31', '2013-12-31',
#                '2014-12-31', '2015-12-31', '2016-12-31', '2017-12-31',
#                '2018-12-31', '2019-12-31', '2020-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
data=pd.date_range(start='1-1-2010',end='12-31-2020', freq='Y')
data
# Out:
# DatetimeIndex(['2010-12-31', '2011-12-31', '2012-12-31', '2013-12-31',
#                '2014-12-31', '2015-12-31', '2016-12-31', '2017-12-31',
#                '2018-12-31', '2019-12-31', '2020-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
data=pd.date_range(start='1-1-2020',end='12-31-2020', freq='10D')
data
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-11', '2020-01-21', '2020-01-31',
#                '2020-02-10', '2020-02-20', '2020-03-01', '2020-03-11',
#                '2020-03-21', '2020-03-31', '2020-04-10', '2020-04-20',
#                '2020-04-30', '2020-05-10', '2020-05-20', '2020-05-30',
#                '2020-06-09', '2020-06-19', '2020-06-29', '2020-07-09',
#                '2020-07-19', '2020-07-29', '2020-08-08', '2020-08-18',
#                '2020-08-28', '2020-09-07', '2020-09-17', '2020-09-27',
#                '2020-10-07', '2020-10-17', '2020-10-27', '2020-11-06',
#                '2020-11-16', '2020-11-26', '2020-12-06', '2020-12-16',
#                '2020-12-26'],
#               dtype='datetime64[ns]', freq='10D')

# %%
import numpy as np
arr=np.random.randint(10,45,366)
arr
# Out:
# array([12, 24, 30, 30, 30, 38, 35, 37, 31, 35, 26, 35, 12, 19, 14, 42, 18,
#        44, 39, 20, 30, 16, 18, 31, 18, 32, 33, 31, 25, 27, 39, 24, 28, 23,
#        19, 18, 44, 13, 17, 40, 31, 13, 37, 11, 38, 14, 17, 10, 19, 24, 38,
#        34, 38, 35, 29, 38, 10, 25, 20, 30, 17, 24, 31, 32, 25, 32, 26, 16,
#        44, 27, 11, 21, 19, 42, 31, 23, 13, 18, 13, 25, 36, 27, 19, 22, 21,
#        22, 11, 16, 30, 13, 17, 18, 40, 42, 17, 28, 33, 20, 16, 30, 21, 35,
#        37, 40, 40, 15, 41, 27, 12, 31, 43, 35, 43, 36, 28, 10, 26, 35, 26,
#        39, 23, 26, 21, 22, 30, 14, 11, 24, 30, 26, 29, 22, 26, 34, 27, 18,
#        14, 44, 15, 26, 35, 37, 41, 20, 37, 25, 31, 31, 37, 30, 16, 30, 19,
#        12, 28, 17, 36, 30, 29, 13, 31, 41, 25, 42, 24, 35, 16, 13, 32, 23,
#        33, 22, 24, 40, 36, 32, 43, 42, 43, 42, 34, 34, 14, 10, 41, 41, 17,
#        13, 31, 13, 36, 38, 22, 14, 22, 36, 39, 29, 39, 12, 34, 13, 24, 42,
# ...

# %%
dates=pd.date_range(start='1-1-2020',end='12-31-2020', freq='D')
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
df=pd.DataFrame(data=arr,columns=['Temp'],index=dates)
df
# Out:
#             Temp
# 2020-01-01    12
# 2020-01-02    24
# 2020-01-03    30
# 2020-01-04    30
# 2020-01-05    30
# ...          ...
# 2020-12-27    24
# 2020-12-28    44
# 2020-12-29    19
# 2020-12-30    21
# 2020-12-31    24
#
# [366 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
arr_st=np.random.randint(100,450,366)
df=pd.DataFrame(data=arr_st,columns=['Stock Price'],index=dates)
df
# Out:
#             Stock Price
# 2020-01-01          134
# 2020-01-02          383
# 2020-01-03          380
# 2020-01-04          345
# 2020-01-05          249
# ...                 ...
# 2020-12-27          446
# 2020-12-28          341
# 2020-12-29          438
# 2020-12-30          173
# 2020-12-31          433
#
# [366 rows x 1 columns]
